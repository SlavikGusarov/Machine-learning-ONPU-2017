# %% [markdown]
# # Практическая работа 2
#
# ## 1. Создать SFrame на основе файла с тестовыми данными people-example.csv

# %%
import graphlab

sf = graphlab.SFrame('people-example.csv')
sf.tail()
# Out:
# Finished parsing file E:\Slavik\Anaconda\Scripts\ONPU ML\Assignment 2\people-example.csv
# Parsing completed. Parsed 56 lines in 0.094012 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,str,str,str,long]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file E:\Slavik\Anaconda\Scripts\ONPU ML\Assignment 2\people-example.csv
# Parsing completed. Parsed 56 lines in 0.081509 secs.
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
#
# Rows: 10
#
# Data:
# +-----------+-----------+-----------+---------+---------+
# |    Имя    |  Фамилия  |   Город   |  Страна | Возраст |
# +-----------+-----------+-----------+---------+---------+
# |    Иван   |  Олейник  |    Киев   | Украина |    23   |
# |   София   | Коваленко |  Варшава  |  Польша |    45   |
# |   Семен   |  Семенов  | Стокгольм |  Швеция |    25   |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |
# | Екатерина | Коваленко | Манчестер |  Англия |    45   |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |
# |    Иван   |  Олейник  |    Киев   | Украина |    23   |
# |   София   | Коваленко |    Киев   | Украина |    22   |
# |   Семен   |  Семенов  | Стокгольм |  Швеция |    25   |
# |   Семен   |  Семенов  | Вашингтон |   США   |    25   |
# +-----------+-----------+-----------+---------+---------+
# [10 rows x 5 columns]

# %% [markdown]
# ## 2. Используя функцию numpy.random.randint() создать новый столбец “Номер дома” с псевдо-случайными значениями в диапазоне [1, 150)

# %%
import numpy as np

sf['Номер дома'] = [ 93,  56,  69,  24,  28, 117,   9,  38, 131,  66,  21,  62,  99,
       148,  69,  94,   2, 112,  75,  36,   4,  83,  57, 117,  62,  62,
        16,  55,  17, 128, 140, 149,  60,  60, 101,   8,  51,  41,  82,
        47,  63, 111, 118, 139, 133,  74, 107,  68,  36, 102,   9,  96,
        92,   5,  13,  57]
sf
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	ФИО	str
# 	Номер дома	int
#
# Rows: 56
#
# Data:
# +-----------+-----------+-----------+---------+---------+
# |    Имя    |  Фамилия  |   Город   |  Страна | Возраст |
# +-----------+-----------+-----------+---------+---------+
# |   Семен   |  Мельник  |   Чикаго  |   США   |    24   |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |
# | Екатерина | Коваленко | Манчестер |  Англия |    45   |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |
# |    Иван   |  Олейник  |    Киев   | Украина |    23   |
# |   София   | Коваленко |    Киев   | Украина |    22   |
# |  Николай  |  Семенов  | Стокгольм |  Швеция |    25   |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |
# | Екатерина | Коваленко | Манчестер |  Англия |    22   |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |
# +-----------+-----------+-----------+---------+---------+
# +------------------------+------------+
# |          ФИО           | Номер дома |
# +------------------------+------------+
# |     Семен Мельник      |     93     |
# |      Елена Бойко       |     56     |
# | Екатерина Коваленко... |     69     |
# |  Александр Шевчук...   |     24     |
# |      Иван Олейник      |     28     |
# |    София Коваленко     |    117     |
# |    Николай Семенов     |     9      |
# |      Елена Бойко       |     38     |
# | Екатерина Коваленко... |    131     |
# |  Александр Шевчук...   |     66     |
# +------------------------+------------+
# [56 rows x 7 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## 3. Создать новый столбец “ФИО”, который объединял бы значения столбцов “Имя” и “Фамилия”

# %%
sf['ФИО'] = sf['Имя'] + ' ' + sf['Фамилия']
sf
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	ФИО	str
# 	Номер дома	int
#
# Rows: 56
#
# Data:
# +-----------+-----------+-----------+---------+---------+
# |    Имя    |  Фамилия  |   Город   |  Страна | Возраст |
# +-----------+-----------+-----------+---------+---------+
# |   Семен   |  Мельник  |   Чикаго  |   США   |    24   |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |
# | Екатерина | Коваленко | Манчестер |  Англия |    45   |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |
# |    Иван   |  Олейник  |    Киев   | Украина |    23   |
# |   София   | Коваленко |    Киев   | Украина |    22   |
# |  Николай  |  Семенов  | Стокгольм |  Швеция |    25   |
# |   Елена   |   Бойко   |   Квебек  |  Канада |    23   |
# | Екатерина | Коваленко | Манчестер |  Англия |    22   |
# | Александр |   Шевчук  | Вашингтон |   США   |    23   |
# +-----------+-----------+-----------+---------+---------+
# +------------------------+------------+
# |          ФИО           | Номер дома |
# +------------------------+------------+
# |     Семен Мельник      |     93     |
# |      Елена Бойко       |     56     |
# | Екатерина Коваленко... |     69     |
# |  Александр Шевчук...   |     24     |
# |      Иван Олейник      |     28     |
# |    София Коваленко     |    117     |
# |    Николай Семенов     |     9      |
# |      Елена Бойко       |     38     |
# | Екатерина Коваленко... |    131     |
# |  Александр Шевчук...   |     66     |
# +------------------------+------------+
# [56 rows x 7 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# ## 4. Используя логический фильтр, вывести все строки, в которых:
# ### a) 'ФИО' = 'Семен Семенов' ИЛИ 'Страна' = 'США'

# %%
sf[(sf['ФИО'] == 'Семен Семенов') | (sf['Страна'] == 'США')]
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	ФИО	str
# 	Номер дома	int
#
# Rows: Unknown
#
# Data:
# +-----------+---------+-----------+--------+---------+
# |    Имя    | Фамилия |   Город   | Страна | Возраст |
# +-----------+---------+-----------+--------+---------+
# |   Семен   | Мельник |   Чикаго  |  США   |    24   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |
# +-----------+---------+-----------+--------+---------+
# +---------------------+------------+
# |         ФИО         | Номер дома |
# +---------------------+------------+
# |    Семен Мельник    |     93     |
# | Александр Шевчук... |     24     |
# | Александр Шевчук... |     66     |
# |    Семен Семенов    |     99     |
# | Александр Шевчук... |     94     |
# | Александр Шевчук... |     83     |
# |    Семен Семенов    |     62     |
# | Александр Шевчук... |     55     |
# | Александр Шевчук... |     60     |
# |    Семен Семенов    |     51     |
# +---------------------+------------+
# [? rows x 7 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %% [markdown]
# ### b) И 'Возраст' != 24

# %%
sf[(sf['ФИО'] == 'Семен Семенов') | (sf['Страна'] == 'США') & (sf['Возраст'] != 24)]
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	ФИО	str
# 	Номер дома	int
#
# Rows: Unknown
#
# Data:
# +-----------+---------+-----------+--------+---------+
# |    Имя    | Фамилия |   Город   | Страна | Возраст |
# +-----------+---------+-----------+--------+---------+
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |
# | Александр |  Шевчук |   Чикаго  |  США   |    23   |
# |   Семен   | Семенов | Стокгольм | Швеция |    25   |
# | Александр |  Шевчук | Вашингтон |  США   |    23   |
# +-----------+---------+-----------+--------+---------+
# +---------------------+------------+
# |         ФИО         | Номер дома |
# +---------------------+------------+
# | Александр Шевчук... |     24     |
# | Александр Шевчук... |     66     |
# |    Семен Семенов    |     99     |
# | Александр Шевчук... |     94     |
# | Александр Шевчук... |     83     |
# |    Семен Семенов    |     62     |
# | Александр Шевчук... |     55     |
# | Александр Шевчук... |     60     |
# |    Семен Семенов    |     51     |
# | Александр Шевчук... |     47     |
# +---------------------+------------+
# [? rows x 7 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.

# %% [markdown]
# ## 5) Вывести количество полученных записей для пункта 4.

# %%
print len(sf[(sf['ФИО'] == 'Семен Семенов') | (sf['Страна'] == 'США')])
print len(sf[(sf['ФИО'] == 'Семен Семенов') | (sf['Страна'] == 'США') & (sf['Возраст'] != 24)])
# Out:
# 16
# 15

# %% [markdown]
# Используя метод SFrame.apply() измените страну проживания во всех записях, где имя = 'Елена' или 'Иван', на 'США'. Отфильтруйте измененный SFrame по стране = 'США'.

# %%
def changer(sf):
    return 'США'

# %%
sf[(sf['Страна'] == 'США') & (sf['Возраст'] == 25)]
# Out:
# Columns:
# 	Имя	str
# 	Фамилия	str
# 	Город	str
# 	Страна	str
# 	Возраст	int
# 	ФИО	str
# 	Номер дома	int
#
# Rows: Unknown
#
# Data:
# +-------+---------+-----------+--------+---------+---------------+------------+
# |  Имя  | Фамилия |   Город   | Страна | Возраст |      ФИО      | Номер дома |
# +-------+---------+-----------+--------+---------+---------------+------------+
# | Семен | Семенов | Вашингтон |  США   |    25   | Семен Семенов |     57     |
# +-------+---------+-----------+--------+---------+---------------+------------+
# [? rows x 7 columns]
# Note: Only the head of the SFrame is printed. This SFrame is lazily evaluated.
# You can use sf.materialize() to force materialization.
